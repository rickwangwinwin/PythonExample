# %% [markdown]
# # Objective and key steps

# %% [markdown]
# Input:
# A table that conatains the historical pricing data
#
# Output:
# A table that still contains the historical pricing data but with additional columns/variables for price percentage change over different time windows
#
# Key steps:
#
# 1. Data import -  the pricing data through Yahoo api and light-touch cleanse
# 2. Feature creation - 1. percentage change on closing price for one and 2.multiple time windows

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import ticker_data_prep
# Out:
# 2021-01-21 16:19:52,529 - data being cooked

# %% [markdown]
# # Data import

# %%
#input for data download
tkr='TSLA'
timespan=1800

# %%
#use yfinance to download ticker data, interval - daily
today=datetime.date.today()
start_date=(today-datetime.timedelta(days=timespan)).strftime('%Y-%m-%d')
enddate=today.strftime('%Y-%m-%d')
data=yf.download(tkr,start_date,enddate)
data.head(2)
# Out:
# 2021-01-21 16:19:54,300 - NumExpr defaulting to 8 threads.
# [*********************100%***********************]  1 of 1 completed
#                  Open    High        Low   Close  Adj Close    Volume
# Date
# 2016-02-17  31.799999  33.868  31.336000  33.736     33.736  29126000
# 2016-02-18  34.484001  34.590  32.953999  33.354     33.354  19438000

# %% [markdown]
# Light touch data cleansing

# %%
df_stock=ticker_data_prep.tkr_data_main(ticker=tkr,timescope=timespan,datatype='daily')
df_stock.head(2)
# Out:
# 2021-01-21 16:19:54,560 - Getting data for TSLA
# [*********************100%***********************]  1 of 1 completed
# 2021-01-21 16:19:54,683 - Column names updated with ticker identifier
# 2021-01-21 16:19:54,683 - Exporting stock daily data for TSLA
# 2021-01-21 16:19:54,701 - row count is 1241
# 2021-01-21 16:19:54,702 - column count is 7
# 2021-01-21 16:19:54,702 - Data has been exported to raw_stock_ticker_data/equity_TSLA_daily.csv
#                  Open    High     Low   Close  Adj Close    Volume ticker
# Date
# 2016-02-17  31.799999  33.868  31.336  33.736     33.736  29126000   TSLA
#             tsla_open  tsla_high   tsla_low  tsla_close  tsla_adj_close  \
# Date
# 2016-02-17  31.799999     33.868  31.336000      33.736          33.736
# 2016-02-18  34.484001     34.590  32.953999      33.354          33.354
#
#             tsla_volume tsla_ticker
# Date
# 2016-02-17   29126000.0        TSLA
# 2016-02-18   19438000.0        TSLA

# %%
#get the column names for open, high,low and close price
for c in df_stock.columns:
    if 'open' in c:
        colnm_open=c
    if 'high' in c:
        colnm_high=c
    if 'low' in c:
        colnm_low=c
    if 'close' in c:
        colnm_close=c

# %% [markdown]
# # Feature creation

# %% [markdown]
# percentage change for one time window

# %%
window=1 
colnm_pct_chg='pct_chg'+'_'+str(window)
df_stock[colnm_pct_chg]=df_stock[colnm_close].pct_change(window)

# %%
df_stock[colnm_pct_chg]
# Out:
# Date
# 2016-02-17         NaN
# 2016-02-18   -0.011323
# 2016-02-19   -0.001139
# 2016-02-22    0.066995
# 2016-02-23   -0.002982
#                 ...
# 2021-01-13    0.005851
# 2021-01-14   -0.011013
# 2021-01-15   -0.022296
# 2021-01-19    0.022260
# 2021-01-20    0.006986
# Name: pct_chg_1, Length: 1241, dtype: float64

# %%
df_stock.head(5)
# Out:
#             tsla_open  tsla_high   tsla_low  tsla_close  tsla_adj_close  \
# Date
# 2016-02-17  31.799999  33.868000  31.336000   33.736000       33.736000
# 2016-02-18  34.484001  34.590000  32.953999   33.354000       33.354000
# 2016-02-19  32.731998  33.498001  32.500000   33.316002       33.316002
# 2016-02-22  34.023998  35.782001  33.970001   35.548000       35.548000
# 2016-02-23  35.231998  36.346001  34.736000   35.442001       35.442001
#
#             tsla_volume tsla_ticker  pct_chg_1
# Date
# 2016-02-17   29126000.0        TSLA        NaN
# 2016-02-18   19438000.0        TSLA  -0.011323
# 2016-02-19   14797000.0        TSLA  -0.001139
# 2016-02-22   25300500.0        TSLA   0.066995
# 2016-02-23   29922000.0        TSLA  -0.002982

# %% [markdown]
# percentage change for multiple time windows

# %%
windows=[i for i in range (1,61)]
for w in windows:
    colnm_pct_chg='pct_chg'+'_'+str(w)
    df_stock[colnm_pct_chg]=df_stock[colnm_close].pct_change(w)
df_stock.head(5)
# Out:
#             tsla_open  tsla_high   tsla_low  tsla_close  tsla_adj_close  \
# Date
# 2016-02-11  30.400000     32.652  29.400000      30.094          30.094
# 2016-02-12  31.000000     31.402  28.740000      30.208          30.208
# 2016-02-16  31.740000     32.590  30.822001      31.034          31.034
# 2016-02-17  31.799999     33.868  31.336000      33.736          33.736
# 2016-02-18  34.484001     34.590  32.953999      33.354          33.354
#
#             tsla_volume tsla_ticker  pct_chg_1  pct_chg_2  pct_chg_3  ...  \
# Date                                                                  ...
# 2016-02-11   71262000.0        TSLA        NaN        NaN        NaN  ...
# 2016-02-12   36179000.0        TSLA   0.003788        NaN        NaN  ...
# 2016-02-16   27969000.0        TSLA   0.027344   0.031235        NaN  ...
# 2016-02-17   29126000.0        TSLA   0.087066   0.116790   0.121021  ...
# 2016-02-18   19438000.0        TSLA  -0.011323   0.074757   0.104145  ...
#
#             pct_chg_51  pct_chg_52  pct_chg_53  pct_chg_54  pct_chg_55  \
# Date
# 2016-02-11         NaN         NaN         NaN         NaN         NaN
# 2016-02-12         NaN         NaN         NaN         NaN         NaN
# 2016-02-16         NaN         NaN         NaN         NaN         NaN
# 2016-02-17         NaN         NaN         NaN         NaN         NaN
# 2016-02-18         NaN         NaN         NaN         NaN         NaN
#
#             pct_chg_56  pct_chg_57  pct_chg_58  pct_chg_59  pct_chg_60
# Date
# 2016-02-11         NaN         NaN         NaN         NaN         NaN
# 2016-02-12         NaN         NaN         NaN         NaN         NaN
# 2016-02-16         NaN         NaN         NaN         NaN         NaN
# 2016-02-17         NaN         NaN         NaN         NaN         NaN
# 2016-02-18         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 67 columns]

# %%
df_stock[list(filter(lambda x:'pct_chg' in x,df_stock.columns))].describe()
# Out:
#          pct_chg_1    pct_chg_2    pct_chg_3    pct_chg_4    pct_chg_5  \
# count  1240.000000  1239.000000  1238.000000  1237.000000  1236.000000
# mean      0.003357     0.006745     0.010170     0.013574     0.017033
# std       0.036515     0.052285     0.064935     0.076995     0.087038
# min      -0.210628    -0.212982    -0.339175    -0.355597    -0.430459
# 25%      -0.013859    -0.019188    -0.023508    -0.026906    -0.030122
# 50%       0.001590     0.005186     0.007439     0.009503     0.012480
# 75%       0.019496     0.031308     0.040912     0.049350     0.055416
# max       0.198949     0.363512     0.384279     0.526808     0.564756
#
#          pct_chg_6    pct_chg_7    pct_chg_8    pct_chg_9   pct_chg_10  ...  \
# count  1235.000000  1234.000000  1233.000000  1232.000000  1231.000000  ...
# mean      0.020410     0.023633     0.026891     0.030172     0.033376  ...
# std       0.095736     0.103218     0.110680     0.118156     0.124896  ...
# min      -0.440255    -0.405888    -0.486524    -0.501449    -0.518052  ...
# 25%      -0.031400    -0.034051    -0.035656    -0.042599    -0.046897  ...
# 50%       0.014343     0.015912     0.018929     0.020733     0.022838  ...
# 75%       0.063301     0.070383     0.075073     0.085753     0.090188  ...
# max       0.589656     0.570518     0.605893     0.639734     0.658833  ...
#
#         pct_chg_51   pct_chg_52   pct_chg_53   pct_chg_54   pct_chg_55  \
# count  1190.000000  1189.000000  1188.000000  1187.000000  1186.000000
# mean      0.161580     0.164508     0.167568     0.170629     0.173874
# std       0.349234     0.353479     0.358094     0.362587     0.367683
# min      -0.349221    -0.346968    -0.350876    -0.361429    -0.382777
# 25%      -0.087087    -0.083716    -0.084049    -0.080957    -0.084238
# 50%       0.057041     0.062454     0.061347     0.067169     0.066121
# 75%       0.284105     0.291125     0.286978     0.296163     0.300125
# max       1.754767     1.728792     1.739630     1.780566     1.769235
#
#         pct_chg_56   pct_chg_57   pct_chg_58   pct_chg_59   pct_chg_60
# count  1185.000000  1184.000000  1183.000000  1182.000000  1181.000000
# mean      0.177099     0.180246     0.183566     0.186970     0.190396
# std       0.372784     0.377027     0.382113     0.387273     0.392626
# min      -0.380641    -0.368401    -0.397493    -0.388865    -0.404058
# 25%      -0.084115    -0.083758    -0.086125    -0.083759    -0.084638
# 50%       0.065834     0.069297     0.071038     0.072167     0.076382
# 75%       0.302616     0.313215     0.313583     0.313739     0.314771
# max       1.789189     1.734434     1.837744     1.700607     1.813269
#
# [8 rows x 60 columns]
